# %%
import sys
import os

sys.path.append('../')
from run_model import *

# %%
outcome = 'lri'
run_label = '10_17_no_deriv_prior'
spec_label = 'no_prior'

# %%
model_dir = f'FILEPATH'

# %%
with open(os.path.join(model_dir, f'{outcome}_{spec_label}/{outcome}_mr_obj.pkl'), 'rb') as fopen:
    mr = pickle.load(fopen)

mr.mr_list[0].prior_list
# Out:
# [{'prior_type': 'x_cov_uprior',
#   'x_cov_id': 0,
#   'prior': array([[  1., -inf, -inf, -inf, -inf],
#          [  1.,  inf,  inf,  inf,  inf]])},
#  {'prior_type': 'spline_shape_function_uprior',
#   'x_cov_id': 0,
#   'interval': [0.0, 553.0],
#   'indicator': [0.01, 30.0],
#   'num_points': 100},
#  {'prior_type': 'z_cov_uprior', 'z_cov_id': 0, 'prior': array([[1.e-07],
#          [1.e+00]])}]

# %%
df = pd.read_csv(os.path.join(model_dir, f'{outcome}_{spec_label}/{outcome}_y_samples_fe.csv'))
df.head()
# Out:
#    exposure_spline    draw_0    draw_1    draw_2    draw_3    draw_4  \
# 0             0.00  1.000000  1.000000  1.000000  1.000000  1.000000
# 1             0.01  1.000220  1.000383  1.000253  1.000413  1.000321
# 2             0.02  1.000441  1.000766  1.000505  1.000825  1.000641
# 3             0.03  1.000661  1.001149  1.000758  1.001238  1.000962
# 4             0.04  1.000881  1.001532  1.001010  1.001650  1.001282
#
#      draw_5    draw_6    draw_7    draw_8  ...  draw_990  draw_991  draw_992  \
# 0  1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000  1.000000
# 1  1.000401  1.000217  1.000335  1.000323  ...  1.000176  1.000158  1.000149
# 2  1.000801  1.000434  1.000670  1.000646  ...  1.000352  1.000316  1.000298
# 3  1.001202  1.000652  1.001004  1.000968  ...  1.000528  1.000475  1.000447
# 4  1.001603  1.000869  1.001339  1.001291  ...  1.000703  1.000633  1.000595
#
#    draw_993  draw_994  draw_995  draw_996  draw_997  draw_998  draw_999
# ...
